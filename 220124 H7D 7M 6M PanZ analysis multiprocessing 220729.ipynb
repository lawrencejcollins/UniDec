# %%
from unidec_modules.v3_SeqChrom import *

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
folder = "C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\2201 PanZ repeats 2022 edit\\"
# folder="C:\\Users\\cm19ljc\\Documents\\PROJECT\\Programming\\Data\\PanZ 6M time course repeats"
plate_map = "C:/Users/cm19ljc/Documents/GitHub/UniDec/reaction maps/PanZ sortase time course 1.5 eq gvseyg.xlsx"

# %%
# import multiprocessing, time

# def get_files(folder):
#     filenames = os.listdir(folder)
#     engines = []
#     paths = []
#     for dname, dirs, files in os.walk(folder):

#         for fname in files:

#             if fname[-4:] == "mzML":
#                 paths.append(os.path.join(dname, fname))
#     return paths

# def multi_load(path):
#     eng = SeqChom()
#     eng.load_mzml(path, clear_hdf5=True)
#     return eng

# p = multiprocessing.Pool(processes = multiprocessing.cpu_count()-1)

# paths = get_files(folder)

# start = time.time()
# engines = p.map_async(multi_load, paths)
# p.close()
# p.join()
# print("Complete")
# end = time.time()
# print('total time (s)= ' + str(end-start))

# print(paths)
# # engines = pool.map(multi_load, paths)
# print(engines)

# %%
def multiprocess_unidec(engine):
    try:
        if eng.ticdat[:, 0].max() > 100: 
            eng.ticdat[:, 0] = eng.tic[:, 0] = eng.ticdat[:, 0]/60 # add in check in code?

        eng.config.chrom_peak_width = 0.6
        eng.get_chrom_peaks(lb = 1, ub = 5.5) 
        eng.add_chrom_peaks2() 
        eng.plot_tic(peak_windows = True)
        eng.update_config(masslb = 10000, massub = 20000, peakthresh = 0.05, minmz="")
        eng.process_data()
        eng.run_unidec()
        eng.pick_peaks()
        eng.integrate_all()
        eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [14000, 17000])
        eng.upload_map(plate_map)
        eng.process_maps(groupby = 'Reaction', variable = 'Species')
        eng.peak_match(silent = True)
        eng.normalise_peaks(silent = True)

        eng.plot_data(plot_type='bar', groupby='Species')
        eng.plot_data()
        return eng
    except:
        return None

# %%
# for i, folder in enumerate(folders): 
filenames = os.listdir(folder)
engines = []
for dname, dirs, files in os.walk(folder):

    for fname in files:

        if fname[-4:] == "mzML":
            eng = SeqChrom()

            spectra_path = os.path.join(dname, fname)
            eng.load_mzml(spectra_path, clear_hdf5=True)
            print("loaded {}".format(spectra_path))
            engines.append(eng)
# Out:
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220107 B _340681.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220107 B _340681.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220107 B _340681.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220120 PanZ 6M A r2_341424.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220120 PanZ 6M A r2_341424.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220120 PanZ 6M A r2_341424.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220120 PanZ 6M B r2_341369.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220120 PanZ 6M B r2_341369.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220120 PanZ 6M B r2_341369.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341575.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341575.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341575.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341579.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341579.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341579.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M B_341584.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M B_341584.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M B_341584.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220125 PanZ labelling 37_341752.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220125 PanZ labelling 37_341752.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220125 PanZ labelling 37_341752.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220127 PanZ labelling B_342038.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220127 PanZ labelling B_342038.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220127 PanZ labelling B_342038.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220202 PanZ 2 hrs repeats_34257.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220202 PanZ 2 hrs repeats_34257.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220202 PanZ 2 hrs repeats_34257.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220203 PanZ 2 hrs repeats_34263.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220203 PanZ 2 hrs repeats_34263.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220203 PanZ 2 hrs repeats_34263.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220207 PanZ repeats_342834.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220207 PanZ repeats_342834.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220207 PanZ repeats_342834.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220721 A_340682.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220721 A_340682.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220721 A_340682.mzML
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220721 C_340683.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220721 C_340683.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# loaded C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220721 C_340683.mzML

# %%
engines
# Out:
# [<unidec_modules.v3_SeqChrom.SeqChrom at 0x1d825a04f70>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d825a686a0>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d825a68610>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d827ce9280>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d833f67820>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d833fa2b20>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d83c095d90>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d848349130>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d83c095820>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d8483377f0>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d890dcb610>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d890dcb370>,
#  <unidec_modules.v3_SeqChrom.SeqChrom at 0x1d8a003f070>]

# %%
for eng in engines:
    try:
        if eng.ticdat[:, 0].max() > 100: 
            eng.ticdat[:, 0] = eng.tic[:, 0] = eng.ticdat[:, 0]/60 # add in check in code?

        eng.config.chrom_peak_width = 0.6
        eng.get_chrom_peaks(lb = 1, ub = 5.5) 
        eng.add_chrom_peaks2() 
        eng.plot_tic(peak_windows = True)
        eng.update_config(masslb = 10000, massub = 20000, peakthresh = 0.05, minmz="")
        eng.process_data()
        eng.run_unidec()
        eng.pick_peaks()
        eng.integrate_all()
        eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [14000, 17000])
        eng.upload_map(plate_map)
        eng.process_maps(groupby = 'Reaction', variable = 'Species')
        eng.peak_match(silent = True)
        eng.normalise_peaks(silent = True)

        eng.plot_data(plot_type='bar', groupby='Species')
        eng.plot_data()
    except:
        print(eng.filename)
# Out:
# 1301 2
# Noise Level: 0.04322444821884148 Window: 0.6
# Bad Peak [0.4193     0.69358189] 0.24186699999999994 [0.4193, 0.661167]
# 1.21788 0.21188000000000007
# 2.1363 0.2909099999999998
# 3.07562 0.19117000000000006
# 3.97762 0.1662300000000001
# 5.04997 0.2535799999999995
# Getting scans: [140, 191]
# Length merge axis: 37789
# Getting scans: [357, 427]
# Length merge axis: 37506
# Getting scans: [581, 627]
# Length merge axis: 37779
# Getting scans: [803, 843]
# Length merge axis: 38125
# Getting scans: [1043, 1104]
# Length merge axis: 37516
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.3815036999999961
# Execution Time: 12.275090700000021
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Execution Time: 0.15006079999997723
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220107 B _340681_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1312 2
# Noise Level: 0.05076942282233411 Window: 0.6
# Bad Peak [0.419317   0.68390531] 0.24191599999999996 [0.419317, 0.661233]
# 1.20987 0.14964
# 2.12845 0.20367000000000024
# 3.06783 0.17037000000000013
# 4.01553 0.16208
# 4.94253 0.17454000000000036
# Getting scans: [136, 172]
# Length merge axis: 38933
# Getting scans: [359, 408]
# Length merge axis: 39234
# Getting scans: [586, 627]
# Length merge axis: 38465
# Getting scans: [812, 851]
# Length merge axis: 38587
# Getting scans: [1037, 1079]
# Length merge axis: 38269
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.07176019999999994
# Execution Time: 11.823165499999988
# Execution Time: 0.29628559999997606
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220120 PanZ 6M A r2_341424_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1309 2
# Noise Level: 0.05645383593188863 Window: 0.6
# Bad Peak [0.419117  0.7216518] 0.246033 [0.419117, 0.66515]
# 1.20958 0.19985000000000008
# 2.14085 0.19106999999999985
# 3.08418 0.19945999999999975
# 4.01097 0.1828300000000005
# 4.95023 0.17866999999999944
# Getting scans: [138, 186]
# Length merge axis: 38755
# Getting scans: [362, 408]
# Length merge axis: 38562
# Getting scans: [587, 635]
# Length merge axis: 39265
# Getting scans: [812, 856]
# Length merge axis: 38921
# Getting scans: [1038, 1081]
# Length merge axis: 38628
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.07758129999999142
# Execution Time: 11.968435499999998
# Execution Time: 0.25849009999998884
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220120 PanZ 6M B r2_341369_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1307 2
# Noise Level: 0.06260756260265045 Window: 0.6
# Bad Peak [0.419267   0.81546314] 0.246083 [0.419267, 0.66535]
# 1.18072 0.2036499999999999
# 2.13252 0.1869799999999997
# 3.05927 0.19944999999999968
# 4.01925 0.12051999999999996
# 4.93365 0.18698999999999977
# Getting scans: [131, 180]
# Length merge axis: 38752
# Getting scans: [358, 403]
# Length merge axis: 38409
# Getting scans: [583, 631]
# Length merge axis: 39109
# Getting scans: [811, 840]
# Length merge axis: 38032
# Getting scans: [1033, 1078]
# Length merge axis: 38767
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.0722902999999917
# Execution Time: 13.448615899999993
# Execution Time: 0.426488599999999
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220121 PanZ 6M A_341575_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 715 2
# Noise Level: 0.15789819096772975 Window: 0.6
# 2.10812 0.3818999999999999
# 3.57805 0.12455000000000016
# Getting scans: [298, 390]
# Length merge axis: 43306
# Getting scans: [669, 699]
# Length merge axis: 38903
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06211179999999672
# Execution Time: 6.562574500000011
# Execution Time: 0.17702239999999847
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220121 PanZ 6M A_341579_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# None
# 1316 2
# Noise Level: 0.04363674739202536 Window: 0.6
# Bad Peak [0.41865    0.70327037] 0.24601699999999999 [0.41865, 0.664667]
# 1.20492 0.1994499999999999
# 2.13163 0.18739000000000017
# 3.0797 0.2036500000000001
# 4.01062 0.18280999999999992
# 4.93745 0.18701999999999952
# Getting scans: [137, 185]
# Length merge axis: 38345
# Getting scans: [361, 406]
# Length merge axis: 38632
# Getting scans: [586, 635]
# Length merge axis: 38589
# Getting scans: [811, 855]
# Length merge axis: 38626
# Getting scans: [1036, 1081]
# Length merge axis: 38545
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06044270000001006
# Execution Time: 16.01229409999999
# No handles with labels found to put in legend.
# Execution Time: 0.1705082999999945
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220121 PanZ 6M B_341584_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1314 2
# Noise Level: 0.05218106333593649 Window: 0.6
# Bad Peak [0.419267   0.68896193] 0.24179999999999996 [0.419267, 0.661067]
# 1.19683 0.21599999999999997
# 2.12727 0.2118000000000002
# 3.06588 0.2035199999999997
# 3.99212 0.1869900000000002
# 4.93535 0.19527000000000072
# Getting scans: [135, 187]
# Length merge axis: 39351
# Getting scans: [360, 411]
# Length merge axis: 38793
# Getting scans: [585, 634]
# Length merge axis: 38455
# Getting scans: [810, 855]
# Length merge axis: 38804
# Getting scans: [1035, 1082]
# Length merge axis: 39307
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06399129999999786
# Execution Time: 11.597998200000006
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Execution Time: 0.12518690000001698
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220125 PanZ labelling 37_341752_extracts.txt
# 1309 2
# Noise Level: 0.0655999168560863 Window: 0.6
# Bad Peak [0.419033   0.70587311] 0.241834 [0.419033, 0.660867]
# 1.0555 0.22021000000000002
# 1.99442 0.2119399999999998
# 2.93753 0.19940999999999987
# 3.87643 0.19113999999999987
# 4.82373 0.19526999999999983
# Getting scans: [102, 155]
# Length merge axis: 39534
# Getting scans: [328, 379]
# Length merge axis: 39124
# Getting scans: [553, 601]
# Length merge axis: 38576
# Getting scans: [779, 825]
# Length merge axis: 39055
# Getting scans: [1006, 1053]
# Length merge axis: 39018
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.0665164000000118
# Execution Time: 12.324956100000009
# No handles with labels found to put in legend.
# Execution Time: 0.28865510000002814
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220127 PanZ labelling B_342038_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1309 2
# Noise Level: 0.07545038998933104 Window: 0.6
# Bad Peak [0.418967   0.28037518] 0.23773299999999997 [0.418967, 0.6567]
# 1.14297 0.21611000000000002
# 2.10723 0.16206000000000031
# 3.02155 0.19943
# 3.95617 0.19932999999999979
# 4.91147 0.14949000000000012
# Getting scans: [122, 174]
# Length merge axis: 38522
# Getting scans: [349, 388]
# Length merge axis: 39486
# Getting scans: [572, 620]
# Length merge axis: 38552
# Getting scans: [797, 845]
# Length merge axis: 38817
# Getting scans: [1025, 1061]
# Length merge axis: 38539
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06894110000001774
# Execution Time: 12.86519340000001
# Execution Time: 0.2712089000000333
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220202 PanZ 2 hrs repeats_34257_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1307 2
# Noise Level: 0.0683366221327026 Window: 0.6
# Bad Peak [0.418283   0.25253677] 0.237717 [0.418283, 0.656]
# 1.22545 0.20777
# 2.1481 0.18698000000000015
# 3.0916 0.18698000000000015
# 4.02245 0.19528999999999996
# 4.96172 0.18703000000000003
# Getting scans: [139, 189]
# Length merge axis: 38451
# Getting scans: [364, 409]
# Length merge axis: 37997
# Getting scans: [590, 635]
# Length merge axis: 38213
# Getting scans: [814, 861]
# Length merge axis: 38463
# Getting scans: [1040, 1085]
# Length merge axis: 38206
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06579279999999699
# Execution Time: 13.517618299999981
# No handles with labels found to put in legend.
# Execution Time: 0.1988311000000067
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220203 PanZ 2 hrs repeats_34263_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1306 2
# Noise Level: 0.07736004346852948 Window: 0.6
# Bad Peak [0.41555    0.79366441] 0.254383 [0.41555, 0.669933]
# 1.22698 0.23692000000000002
# 2.14983 0.21614999999999984
# 3.08102 0.21614999999999984
# 4.02452 0.1620200000000005
# 4.9513 0.19119000000000064
# Getting scans: [134, 191]
# Length merge axis: 38477
# Getting scans: [359, 411]
# Length merge axis: 38428
# Getting scans: [584, 636]
# Length merge axis: 38726
# Getting scans: [810, 849]
# Length merge axis: 38083
# Getting scans: [1035, 1081]
# Length merge axis: 38412
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.060596499999974185
# Execution Time: 13.804884000000015
# No handles with labels found to put in legend.
# Execution Time: 0.24805340000000342
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220207 PanZ repeats_342834_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 1306 2
# Noise Level: 0.06790370063559534 Window: 0.6
# Bad Peak [0.419433   0.92263147] 0.24605000000000005 [0.419433, 0.665483]
# 1.30972 0.28678000000000003
# 2.17025 0.19952000000000014
# 3.10548 0.17458000000000018
# 4.02415 0.14549999999999974
# 5.05925 0.19535000000000036
# Getting scans: [150, 219]
# Length merge axis: 38274
# Getting scans: [364, 412]
# Length merge axis: 38306
# Getting scans: [589, 631]
# Length merge axis: 37503
# Getting scans: [815, 850]
# Length merge axis: 37492
# Getting scans: [1057, 1104]
# Length merge axis: 37656
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06414369999998826
# Execution Time: 14.642748900000015
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Execution Time: 0.13004049999995004
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220721 A_340682_extracts.txt
# No handles with labels found to put in legend.
# 1308 2
# Noise Level: 0.05421592980501297 Window: 0.6
# Bad Peak [0.419317   0.85315743] 0.23771599999999998 [0.419317, 0.657033]
# 1.14337 0.34495999999999993
# 2.01622 0.16625999999999985
# 2.9349 0.16211999999999982
# 3.89103 0.17041999999999957
# 4.93447 0.23278
# Getting scans: [110, 193]
# Length merge axis: 38528
# Getting scans: [330, 370]
# Length merge axis: 37959
# Getting scans: [554, 593]
# Length merge axis: 37652
# Getting scans: [780, 821]
# Length merge axis: 37992
# Getting scans: [1019, 1075]
# Length merge axis: 37698
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.06610530000000381
# Execution Time: 14.948718799999995
# Execution Time: 0.27363650000000916
# Peak info saved to: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\UniDec_Figures_and_Files\220721 C_340683_extracts.txt
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# n.b. lowering the peakthresh may result in noise being recognised as a peak and thereby generating false data.
# >start high e.g. 0.1 and lower as appropriate

# %%
df = eng.data_df['PanZ']

df.plot.bar(rot = 0)
plt.legend(bbox_to_anchor=(1,1), loc="upper left")
plt.title('Sortase 1')
plt.show()

# %%
# dfs = [list(eng.data_df.values())[0] for eng in engines]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e327353c440f> in <module>
# ----> 1 dfs = [list(eng.data_df.values())[0] for eng in engines]
#
# <ipython-input-10-e327353c440f> in <listcomp>(.0)
# ----> 1 dfs = [list(eng.data_df.values())[0] for eng in engines]
#
# AttributeError: 'SeqChrom' object has no attribute 'data_df'

# %%
delete = ["220120 PanZ 6M A r2_341424_RE6_01_82312.d.mzML",

"220125 PanZ labelling 37_341752_BB6_01_82457.d.mzML", "220121 PanZ 6M A_341579.mzML","220125 PanZ labelling 37_341752.mzML"
]

delete = [folder+d for d in delete]
dfs=[]
for i, eng in enumerate(engines):
    if eng.path not in delete:
        try:
            
            dfs.append(list(eng.data_df.values())[0])
#             print("appended", eng.path)
        except:
            print(i)
            print(engines[i].path)
    else:
        print("not appended", eng.path)
delete
# Out:
# not appended C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220121 PanZ 6M A_341579.mzML
# not appended C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\2201 PanZ repeats 2022 edit\220125 PanZ labelling 37_341752.mzML
# ['C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\2201 PanZ repeats 2022 edit\\220120 PanZ 6M A r2_341424_RE6_01_82312.d.mzML',
#  'C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\2201 PanZ repeats 2022 edit\\220125 PanZ labelling 37_341752_BB6_01_82457.d.mzML',
#  'C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\2201 PanZ repeats 2022 edit\\220121 PanZ 6M A_341579.mzML',
#  'C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\2201 PanZ repeats 2022 edit\\220125 PanZ labelling 37_341752.mzML']

# %%
for

# %%
# for eng in engines:
#     df = eng.data_df['PanZ']
#     df.plot.bar(rot = 0)
#     plt.legend(bbox_to_anchor=(1,1), loc="upper left")
#     plt.title(eng.path)
#     print(eng.path)
#     plt.show()

# %%
import pandas as pd

# %%
# df_concat = pd.concat(dfs)
# # df_concat=df_concat.groupby(df_concat.index)
# df_concat
# # trans = df_concat.T
# # trans['Species']=trans.index
# # trans.T
# Out:
#           PanZ  PanZ-GVSEG  PanZ-GVSEYG   PanZ-OH
# Time
# 30    0.696103    0.061222     0.242675  0.000000
# 60    0.455240    0.102240     0.406850  0.035671
# 90    0.351485    0.131901     0.516614  0.000000
# 120   0.236175    0.152566     0.611259  0.000000
# 180   0.116466    0.181850     0.639311  0.062373
# 30    0.163250    0.000000     0.836750  0.000000
# 60    0.540172    0.089207     0.370621  0.000000
# 90    0.505951    0.073954     0.316980  0.103115
# 120   0.505680    0.100551     0.352710  0.041059
# 180   0.386244    0.111629     0.439748  0.062379
# 30    0.800464    0.000000     0.199536  0.000000
# 60    0.502103    0.109029     0.388868  0.000000
# 90    0.519851    0.094171     0.358028  0.027950
# 120   0.449825    0.099236     0.405207  0.045733
# 180   0.330195    0.128152     0.470962  0.070690
# 30    0.398072    0.103704     0.498224  0.000000
# 60    0.687692    0.064329     0.247979  0.000000
# 90    0.585136    0.054679     0.360184  0.000000
# 120   0.000000    0.000000     1.000000  0.000000
# 180   0.418768    0.106802     0.413365  0.061065
# 30    0.783373    0.000000     0.216627  0.000000
# 60    0.581792    0.080357     0.337851  0.000000
# 90    0.473078    0.101898     0.383656  0.041368
# 120   0.355599    0.107280     0.451651  0.085471
# 180   0.217181    0.150674     0.548725  0.083421
# 30    0.595707    0.000000     0.404293  0.000000
# 60    0.363918    0.118204     0.422547  0.095331
# 90    0.407595    0.094942     0.375850  0.121612
# 120   0.342939    0.111583     0.459407  0.086071
# 180   0.202268    0.141886     0.509934  0.145912
# 30    0.292510    0.119603     0.587887  0.000000
# 60    0.000000    0.000000     1.000000  0.000000
# 90    0.374952    0.119488     0.505560  0.000000
# 120   0.368376    0.124652     0.506971  0.000000
# 180   0.000000    0.000000     1.000000  0.000000
# 30    0.267504    0.116993     0.576857  0.038646
# 60    0.288141    0.132586     0.526964  0.052308
# 90    0.305104    0.134558     0.462581  0.097757
# 120   0.381309    0.115958     0.461997  0.040736
# 180   0.356612    0.125027     0.470038  0.048324
# 30    0.310777    0.120444     0.530162  0.038617
# 60    0.390813    0.115888     0.454324  0.038975
# 90    0.431806    0.101830     0.404617  0.061748
# 120   0.327360    0.110856     0.561784  0.000000
# 180   0.409523    0.116464     0.474013  0.000000
# 30    0.903672    0.000000     0.096329  0.000000
# 60    0.799342    0.050386     0.150272  0.000000
# 90    0.836043    0.000000     0.163957  0.000000
# 120   0.821153    0.000000     0.178847  0.000000
# 180   0.703599    0.050712     0.245689  0.000000
# 30    0.734709    0.066884     0.198407  0.000000
# 60    0.571559    0.076861     0.351580  0.000000
# 90    0.471436    0.095557     0.433007  0.000000
# 120   0.347029    0.127999     0.524972  0.000000
# 180   0.218244    0.141941     0.590996  0.048818

# %%
colors = {'PanZ':'blue', 'PanZ-GVSEG':'orange', "PanZ-GVSEYG":'green', 'PanZ-OH':'red'}

for time, df in df_concat:
#     plt.plot(float(name), df)
    t = [float(time)]*len(df)
    for species in df.columns:
        plt.scatter(t, df[species], color=colors[species], marker = 'x')
for species in df.columns:
    plt.scatter([],[], color=colors[species], marker='x', label=species)
    plt.legend(bbox_to_anchor=(1, 1))

# %%
import seaborn as sns

# %%
df_joined=pd.concat(dfs)
df_joined.index=np.array(df_joined.index, dtype=float)
df_joined['Time']= df_joined.index
df_joined.reset_index(inplace=True, drop=True)
melt = df_joined.melt('Time', var_name='Species', value_name='Intensity')
melt.head()
# Out:
#     Time Species  Intensity
# 0   30.0    PanZ   0.696103
# 1   60.0    PanZ   0.455240
# 2   90.0    PanZ   0.351485
# 3  120.0    PanZ   0.236175
# 4  180.0    PanZ   0.116466

# %%
melt_PanZ=melt[(melt['Species']=='PanZ-GVSEYG') | (melt['Species']=='PanZ')]

melt_PanZ.head()
sns.catplot(data=melt_PanZ, hue='Species', x='Time', y='Intensity', kind='box')

# %%
sns.relplot(data=melt, hue='Species', x='Time', y='Intensity', kind='line')

# %%
std = df_concat.std()
means = df_concat.mean()
means.index = [float(i) for i in means.index]
means = means.sort_index()

# %%
colors=['blue', 'green', 'red', 'yellow']

# %%
means.plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

for species in means.columns:
    ax.errorbar(means.index, means[species], yerr=std[species], capsize = 10, marker = "x", ls = "--", label=species)
    plt.title(species)
    plt.legend(bbox_to_anchor=(1,1), loc="upper left")
plt.show()

# %%
fig, ax = plt.subplots()

for species in means.columns:
    ax.errorbar(means.index, means[species], yerr=std[species], capsize = 10, fmt='.', label = species)
#     ax.bar(x=means.index, height=means[species], width = 5)
    plt.title(species)
    plt.legend(bbox_to_anchor=(1,1), loc="upper left")
plt.show()

# %%
def colorcode(lst, cmap = 'rainbow'):
    c = []
    cmap = plt.get_cmap(cmap)
    colors = cmap(np.linspace(0, 1, len(lst)))
    for i, s in enumerate(lst):
        c.append(colors[i])
    return c

# %%
# delete = ["D:\220121\PanZ 6M time course repeats\220120 PanZ 6M A r2_341424_RE6_01_82312.d.mzML",

# "D:\220121\PanZ 6M time course repeats\220125 PanZ labelling 37_341752_BB6_01_82457.d.mzML"
# ]

dfs = [list(eng.data_df.values())[0] for eng in engines if eng.path not in delete]

df_concat = pd.concat(dfs)
df_concat=df_concat.groupby(df_concat.index)
std = df_concat.std()
means = df_concat.mean()
means.index = [float(i) for i in means.index]
means = means.sort_index()
fig, ax = plt.subplots(1, (len(means.columns)), sharey=True, dpi=100, figsize = (9, 5))
colors = colorcode(list(means.columns), cmap='Accent')
for i, species in enumerate(means.columns):
    
    ax[i].errorbar(means.index, means[species], yerr=std[species], capsize = 10, fmt='.')
    ax[i].bar(x=means.index, height=means[species], width = 10, color=colors[i])
    ax[i].set_title(species)
#     ax[i].set_ylabel("% Intensity")
#     ax[i].set_xlabel("Time")
    fig.text(0.5, 0.01, 'Time', ha='center')
    fig.text(0.01, 0.5, '% Intensity', va='center', rotation='vertical')
    plt.tight_layout()
#     ax.set_ylim(bottom=0)
plt.show()
