# %%
from unidec_modules.v3_SeqChrom import *

# %%
eng = SeqChrom()
# Out:
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
directory = "D:\\211117 charlie ms\\MZML2\\7M"

plate_map = map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\charlie_7M.xlsx"

# %%
eng.load_multi_single(directory)
# Out:
# Error: No HDF5 file present. Please create an HDF5 file first
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020EF2588E80>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 100 uM AYLPETGG 1 h_BD2_01_80283.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 100 uM AYLPETGG 1 h_BD2_01_80283.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 100 uM AYLPETGG 1 h_BD2_01_80283.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 715 2
# Noise Level: 0.16156276853543483 Window: 0.2
# Bad Peak [0.7583     0.31749349] 0.029067000000000065 [0.7583, 0.787367]
# 1.9918 0.08717999999999981
# 3.5742 0.13707000000000003
# Getting scans: [275, 323]
# Length merge axis: 40841
# 0
# 1
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020EC56FD8B0>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 100 uM AYLPETGG 2 h_BE8_01_80305.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 100 uM AYLPETGG 2 h_BE8_01_80305.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 100 uM AYLPETGG 2 h_BE8_01_80305.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 701 2
# Noise Level: 0.14872419419398855 Window: 0.2
# Bad Peak [0.75785    0.26961209] 0.02905000000000002 [0.75785, 0.7869]
# 1.96582 0.10382000000000025
# 3.27827 0.26994000000000007
# 3.54428 0.12875000000000014
# Getting scans: [276, 323]
# Length merge axis: 41853
# 1
# 2
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020EC596A190>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 105 uM AYLPETGG 1 h_BD3_01_80287.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 105 uM AYLPETGG 1 h_BD3_01_80287.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 105 uM AYLPETGG 1 h_BD3_01_80287.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 715 2
# Noise Level: 0.15807725815331197 Window: 0.2
# Bad Peak [0.758167  0.2984114] 0.024915999999999938 [0.758167, 0.783083]
# 2.02487 0.09550000000000014
# 3.58643 0.14116000000000017
# Getting scans: [275, 323]
# Length merge axis: 41080
# 2
# 3
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020ECCAC1130>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 105 uM AYLPETGG 2 h_GA1_01_80306.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 105 uM AYLPETGG 2 h_GA1_01_80306.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 105 uM AYLPETGG 2 h_GA1_01_80306.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 717 2
# Noise Level: 0.15755600280627233 Window: 0.2
# Bad Peak [0.75785    0.32114337] 0.029066999999999954 [0.75785, 0.786917]
# 2.01648 0.09135999999999989
# Bad Peak [2.54393    0.19190425] 1.5824000000000003 [1.8171, 3.3995]
# Bad Peak [3.37458    0.18738617] 1.5824000000000003 [1.8171, 3.3995]
# 3.6323 0.10382999999999987
# Getting scans: [275, 323]
# Length merge axis: 40817
# 3
# 4
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020ECCAC1EB0>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 110 uM AYLPETGG 1 h_BD4_01_80288.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 110 uM AYLPETGG 1 h_BD4_01_80288.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 110 uM AYLPETGG 1 h_BD4_01_80288.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 721 2
# Noise Level: 0.15533878776773657 Window: 0.2
# Bad Peak [0.755433   0.29651589] 0.029066999999999954 [0.755433, 0.7845]
# 2.03033 0.09553000000000011
# 3.58355 0.14118999999999993
# Getting scans: [276, 323]
# Length merge axis: 40828
# 4
# 5
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020ECCAC1BE0>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 110 uM AYLPETGG 2 h_GA2_01_80307.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 110 uM AYLPETGG 2 h_GA2_01_80307.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 110 uM AYLPETGG 2 h_GA2_01_80307.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 717 2
# Noise Level: 0.13674938373164125 Window: 0.2
# Bad Peak [0.758367   0.24073525] 0.029032999999999975 [0.758367, 0.7874]
# 2.02515 0.09965000000000002
# Bad Peak [3.3792     0.17499613] 1.5783299999999998 [1.8258, 3.40413]
# 3.62035 0.11628000000000016
# Getting scans: [275, 323]
# Length merge axis: 41552
# 5
# 6
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020ECCF6DA90>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 120 uM AYLPETGG 1 h_BD5_01_80289.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 120 uM AYLPETGG 1 h_BD5_01_80289.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 120 uM AYLPETGG 1 h_BD5_01_80289.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 716 2
# Noise Level: 0.15494069862927304 Window: 0.2
# Bad Peak [0.755517   0.29359372] 0.02491600000000005 [0.755517, 0.780433]
# 2.0263 0.09966000000000008
# 3.58367 0.1453500000000001
# Getting scans: [276, 323]
# Length merge axis: 40945
# 6
# 7
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.4.4.0
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000020ED9200FD0>
# Opening HDF5 File: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 120 uM AYLPETGG 2 h_GA3_01_80308.d.hdf5
# Reading mzML: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 120 uM AYLPETGG 2 h_GA3_01_80308.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211117 charlie ms\MZML2\7M\20211116 2 uM Srt7M 120 uM AYLPETGG 2 h_GA3_01_80308.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# Imported Data. Constructing TIC
# Done
# 714 2
# Noise Level: 0.15249077622353968 Window: 0.2
# Bad Peak [0.757817   0.27693841] 0.02908300000000008 [0.757817, 0.7869]
# 2.03712 0.08719999999999972
# 3.37037 0.3198099999999999
# 3.60728 0.12042999999999981
# Getting scans: [275, 323]
# Length merge axis: 40302
# 7
# 8
# 8

# %%
# TIC/time point invalidation 
# add option to delete index in TIC data 
# add option to invalidate specific time/species 
# add option to plot bar chart instead of scatter/line - especially useful for comparison of diff species

# %% [markdown]
# n.b. lowering the peakthresh may result in noise being recognised as a peak and thereby generating false data.
# >start high e.g. 0.1 and lower as appropriate

# %%
eng.update_config(masslb = 12000, massub = 14000, minmz = 775, peakthresh = 0.02)
eng.process_data()
eng.run_unidec()
eng.pick_peaks()
eng.integrate_all()
# Out:
# Execution Time: 0.12415219999999749
# Execution Time: 5.659689499999999
# Execution Time: 0.15823290000000156
# Peak info saved to: UniDec_Figures_and_Files\.hdf5_extracts.txt

# %%
eng.plot_all(dtype = 'data2', combine = False, cmap = 'viridis')

# %%
eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [12000, 14000])

# %%
eng.upload_map(map_path)
# Out:
# (  Reaction     Species  Concentration Units     Mass Reagent_Type Sequence
#  0  ctb_mix    labelled            NaN    uM  12530.0      Protein      NaN
#  1  ctb_mix  unlabelled            NaN    uM  11855.0      Protein      NaN,
#              Type     Reaction Time  7M  Damp  AYLPETGG  Species  Valid
#  Well ID
#  1        Protein  charlie_h7d    1   2     2       100      NaN   True
#  2        Protein  charlie_h7d    2   2     2       100      NaN   True
#  3        Protein  charlie_h7d    1   2     2       105      NaN   True
#  4        Protein  charlie_h7d    2   2     2       105      NaN   True
#  5        Protein  charlie_h7d    1   2     2       110      NaN   True
#  6        Protein  charlie_h7d    2   2     2       110      NaN   True
#  7        Protein  charlie_h7d    1   2     2       120      NaN   True
#  8        Protein  charlie_h7d    2   2     2       120      NaN   True)

# %%
eng.pmap
# Out:
#             Type     Reaction Time  7M  Damp  AYLPETGG  Species  Valid
# Well ID
# 1        Protein  charlie_h7d    1   2     2       100      NaN   True
# 2        Protein  charlie_h7d    2   2     2       100      NaN   True
# 3        Protein  charlie_h7d    1   2     2       105      NaN   True
# 4        Protein  charlie_h7d    2   2     2       105      NaN   True
# 5        Protein  charlie_h7d    1   2     2       110      NaN   True
# 6        Protein  charlie_h7d    2   2     2       110      NaN   True
# 7        Protein  charlie_h7d    1   2     2       120      NaN   True
# 8        Protein  charlie_h7d    2   2     2       120      NaN   True

# %%
eng.speciesmap
# Out:
#   Reaction     Species  Concentration Units     Mass Reagent_Type Sequence
# 0  ctb_mix    labelled            NaN    uM  12530.0      Protein      NaN
# 1  ctb_mix  unlabelled            NaN    uM  11855.0      Protein      NaN

# %%
eng.process_maps()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-32376441d60b> in <module>
# ----> 1 eng.process_maps()
#
# ~\Documents\GitHub\UniDec\unidec_modules\v3_SeqChrom.py in process_maps(self, groupby)
#     378
#     379         for index, row in self.pmap2.iterrows():
# --> 380             for specs in row['Species']:
#     381                 row[specs] = deepcopy(row[specs])
#     382                 row[specs].coord = row.name
#
# TypeError: 'float' object is not iterable

# %%
eng.peak_match(silent = True)

# %%
eng.normalise_peaks(silent = True)

# %%
eng.plot_data()

# %%
eng.invalidate(90, 'Time')
eng.plot_data()

# %%
eng.plot_data(plot_type='bar')

# %%
eng.initial_rate(thresh=0.8)

# %%
eng.ratedict

# %%
eng.__dict__

# %%
def foo(bar, result, index):
    print('hello {0}'.format(bar))
    result[index] = "foo"

from threading import Thread

threads = [None] * 10
results = [None] * 10

for i in range(len(threads)):
    threads[i] = Thread(target=foo, args=('world!', results, i))
    threads[i].start()

# do some other stuff

for i in range(len(threads)):
    threads[i].join()

print(" ".join(results))
