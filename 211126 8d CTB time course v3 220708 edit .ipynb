# %%
from unidec_modules.v3_SeqChrom import *

# %%
eng = SeqChrom()
# Out:
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
folder = "C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\"

# 25% H7D 37 degrees
spectra_paths = [folder+"211206 CTB H7D GV 37d 25pc_3386.mzML", 
folder+"211206 ctb gv h7d 25pc 37d p2_3.mzML"]
map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\CTB h7d time course 25pc obf.xlsx"

# # 10%
# spectra_paths = ["C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211124 CTB GV tc part 1_337339_RC3_01_80616.d.mzML", 
# "C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211124 CTB GV tc part 2_337340_RC6_01_80618.d.mzML"]
# map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\CTB h7d time course 10pc obf.xlsx"

# %%
eng.load_multi_mzml(spectra_paths, plot = True, clear_hdf5 = True)
# Out:
# Error: No HDF5 file present. Please create an HDF5 file first
# ['C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211206 CTB H7D GV 37d 25pc_3386.mzML', 'C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211206 ctb gv h7d 25pc 37d p2_3.mzML']
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x00000224DDFC7FD0>
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211206 CTB H7D GV 37d 25pc_3386.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211206 CTB H7D GV 37d 25pc_3386.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1359 2
# Noise Level: 0.055395791039069234 Window: 0.2
# 0.70665 0.337434
# 1.15973 0.20783000000000018
# 2.09485 0.16208
# 3.06332 0.21613000000000016
# 3.98193 0.19953999999999983
# 4.89635 0.1704099999999995
# Bad Peak [6.2383     0.13308723] 0.03324999999999978 [6.20505, 6.2383]
# Getting scans: [123, 173]
# Length merge axis: 38302
# Getting scans: [348, 387]
# Length merge axis: 38211
# Getting scans: [580, 632]
# Length merge axis: 38682
# Getting scans: [800, 848]
# Length merge axis: 38863
# Getting scans: [1023, 1064]
# Length merge axis: 38486
# 4
# LENGTH: 5
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x00000224B150B8E0>
# hdf5 does not exist
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211206 ctb gv h7d 25pc 37d p2_3.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211206 ctb gv h7d 25pc 37d p2_3.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1308 2
# Noise Level: 0.061374482048395115 Window: 0.2
# 0.706867 0.13343300000000002
# 1.26793 0.19945999999999997
# 2.21137 0.24106999999999967
# 3.14663 0.18700000000000028
# 4.04433 0.14132000000000033
# 5.04162 0.1829300000000007
# Getting scans: [150, 198]
# Length merge axis: 38333
# Getting scans: [374, 432]
# Length merge axis: 38337
# Getting scans: [599, 644]
# Length merge axis: 38102
# Getting scans: [821, 855]
# Length merge axis: 37862
# Getting scans: [1056, 1100]
# Length merge axis: 37790
# 4
# LENGTH: 10
# 10
# False

# %%
# TIC/time point invalidation 
# add option to delete index in TIC data 
# add option to invalidate specific time/species 
# add option to plot bar chart instead of scatter/line - especially useful for comparison of diff species

# %% [markdown]
# n.b. lowering the peakthresh may result in noise being recognised as a peak and thereby generating false data.
# >start high e.g. 0.1 and lower as appropriate

# %%
eng.update_config(masslb = 10000, massub = 20000, minmz = 500, peakthresh = 0.02)

# eng.update_config(masslb = 10000, massub = 20000, peakthresh = 0.01, datanorm = 0, 
#                  beta = 0, peaknorm = 0, exnorm = 0, numit=100, numz=50,
#                  endz=100, startz=10,zzsig=1.0, psig=1.0,mzsig=1.0,psfun=0,msig=0.0,molig=0.0,
#                  massbins=1.0,mtabsig=0.0, subbuff=0.0, subtype=2, mzbins=0.0, 
#                  peakwindow=10.0, smooth = 0)
# eng.update_config(masslb = 10000, massub = 20000, minmz = 500, peakthresh = 0.02, mzbins = 0,
#         linflag = 2,
#         adductmass = 1.007276467,
#         # Narrow Charge and Mass Range
#         startz = 1,
#         endz = 50,

#         # Increase mass resolution and lower peak shape
#         massbins = 10,
#         mzsig = 1,
#         psfun = 0,
#         isotopemode = 0,
#         molig = 0,
#         msig = 0,
#         numit = 50,
#         zzsig = 1,
#         psig = 1,
#         poolflag = 2)

eng.process_data()
eng.run_unidec()
eng.pick_peaks()
eng.integrate_all()
# Out:
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.1552082999999982
# Execution Time: 16.128410000000002
# Execution Time: 0.6921830999999941
# Peak info saved to: UniDec_Figures_and_Files\.hdf5_extracts.txt

# %%
eng.plot_all(dtype = 'data2', combine = False, cmap = 'viridis')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [12000, 14000])
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
eng.upload_map(map_path)
# Out:
# (         Reaction       Species  Concentration Units      Mass Reagent_Type  \
#  0  CTB Sortase 25        CTB-H6          100.0    uM  13597.42      Protein
#  1  CTB Sortase 25  CTB-labelled            NaN    uM  13151.97      Protein
#
#    Sequence
#  0      NaN
#  1      NaN  ,
#              Type        Reaction Time  Injection  Species  Valid
#  Well ID
#  1        Protein  CTB Sortase 25   15          1      NaN   True
#  2        Protein  CTB Sortase 25   30          1      NaN   True
#  3        Protein  CTB Sortase 25   45          1      NaN   True
#  4        Protein  CTB Sortase 25   60          1      NaN   True
#  5        Protein  CTB Sortase 25   75          1      NaN   True
#  6        Protein  CTB Sortase 25   90          2      NaN   True
#  7        Protein  CTB Sortase 25  105          2      NaN   True
#  8        Protein  CTB Sortase 25  120          2      NaN   True
#  9        Protein  CTB Sortase 25  150          2      NaN   True
#  10       Protein  CTB Sortase 25  180          2      NaN   True)

# %%
eng.pmap
# Out:
#             Type        Reaction Time  Injection  Species  Valid
# Well ID
# 1        Protein  CTB Sortase 25   15          1      NaN   True
# 2        Protein  CTB Sortase 25   30          1      NaN   True
# 3        Protein  CTB Sortase 25   45          1      NaN   True
# 4        Protein  CTB Sortase 25   60          1      NaN   True
# 5        Protein  CTB Sortase 25   75          1      NaN   True
# 6        Protein  CTB Sortase 25   90          2      NaN   True
# 7        Protein  CTB Sortase 25  105          2      NaN   True
# 8        Protein  CTB Sortase 25  120          2      NaN   True
# 9        Protein  CTB Sortase 25  150          2      NaN   True
# 10       Protein  CTB Sortase 25  180          2      NaN   True

# %%
eng.speciesmap
# Out:
#          Reaction       Species  Concentration Units      Mass Reagent_Type  \
# 0  CTB Sortase 25        CTB-H6          100.0    uM  13597.42      Protein
# 1  CTB Sortase 25  CTB-labelled            NaN    uM  13151.97      Protein
#
#   Sequence
# 0      NaN
# 1      NaN

# %%
eng.process_maps()

# %%
eng.peak_match(silent = True)

# %%
eng.normalise_peaks(silent = True)

# %%
eng.plot_data()

# %%
for key, df in eng.data_df.items():
    for species in df.columns:
        group = np.array(df[species])
        if ~np.all((group==0)):
            plt.scatter(df[species].index, group, label=species, marker='x')
            pass
            
#             df[species].plot.scatter(label = species)
np.array(df[species])
# Out:
# array([0.        , 0.        , 0.11189189, 0.        , 0.32264099,
#        0.37592012, 0.55942506, 0.61152124, 0.92214274, 1.        ])

# %%
eng.invalidate(60, 'Time')
eng.plot_data()
# Out:
# Time:60 successfully invalidated
# Time:60 successfully invalidated

# %%
# eng.plot_data(plot_type='scatter')

# %%
eng.initial_rate(thresh=0.8)

# %%
eng.ratedict
# Out:
# {'CTB Sortase 25': CTB-H6         -0.005824
#  CTB-labelled    0.005824
#  dtype: float64}
