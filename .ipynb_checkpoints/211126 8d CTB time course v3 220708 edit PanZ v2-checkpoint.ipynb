# %%
from unidec_modules.v3_SeqChrom import *

# %%
eng = SeqChrom()
# Out:
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
folder = "C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\"

# # 25% H7D 37 degrees
# spectra_paths = folder+"211206 CTB H7D GV 37d 25pc_3386_BE2_01_81035.d.mzML", 
# folder+"211206 ctb gv h7d 25pc 37d p2_3_BE6_01_81039.d.mzML"
# map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\CTB h7d time course 25pc obf.xlsx"

# 10%
spectra_paths = ["C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211124 CTB GV tc part 1_337339_RC3_01_80616.d.mzML", 
"C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211124 CTB GV tc part 2_337340_RC6_01_80618.d.mzML"]
map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\CTB h7d time course 10pc obf.xlsx"

# %%
eng.load_multi_mzml(spectra_paths, plot = True, clear_hdf5 = True)
# Out:
# Error: No HDF5 file present. Please create an HDF5 file first
# ['C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211124 CTB GV tc part 1_337339_RC3_01_80616.d.mzML', 'C:\\Users\\cm19ljc\\OneDrive - University of Leeds\\DATA\\AccMass Analysis\\211124 CTB GV tc part 2_337340_RC6_01_80618.d.mzML']
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x00000199FD875940>
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211124 CTB GV tc part 1_337339_RC3_01_80616.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211124 CTB GV tc part 1_337339_RC3_01_80616.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1309 2
# Noise Level: 0.054029524846904355 Window: 0.2
# Bad Peak [0.4188     0.74781163] 0.246033 [0.4188, 0.664833]
# 1.20103 0.18701000000000012
# 2.27335 0.17036000000000007
# 3.17945 0.18701999999999996
# 4.12283 0.1787099999999997
# 5.0621 0.18698000000000015
# 5.98893 0.05401999999999951
# Getting scans: [135, 180]
# Length merge axis: 37955
# Getting scans: [396, 437]
# Length merge axis: 38387
# Getting scans: [614, 659]
# Length merge axis: 38433
# Getting scans: [839, 882]
# Length merge axis: 38420
# Getting scans: [1064, 1109]
# Length merge axis: 38360
# 4
# LENGTH: 5
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x00000199DFC82C70>
# Reading mzML: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211124 CTB GV tc part 2_337340_RC6_01_80618.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: C:\Users\cm19ljc\OneDrive - University of Leeds\DATA\AccMass Analysis\211124 CTB GV tc part 2_337340_RC6_01_80618.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1310 2
# Noise Level: 0.08776075957065196 Window: 0.2
# Bad Peak [0.418633   0.79122694] 0.241867 [0.418633, 0.6605]
# 1.08427 0.17449000000000003
# 2.00275 0.18696999999999986
# 2.94185 0.17035
# 3.87702 0.18700000000000028
# 4.81215 0.19526999999999983
# 5.9344 0.05817999999999923
# Getting scans: [109, 151]
# Length merge axis: 38068
# Getting scans: [329, 374]
# Length merge axis: 38297
# Getting scans: [555, 596]
# Length merge axis: 38652
# Getting scans: [780, 825]
# Length merge axis: 38424
# Getting scans: [1005, 1052]
# Length merge axis: 38107
# 4
# LENGTH: 10
# 10
# False

# %%
# TIC/time point invalidation 
# add option to delete index in TIC data 
# add option to invalidate specific time/species 
# add option to plot bar chart instead of scatter/line - especially useful for comparison of diff species

# %% [markdown]
# n.b. lowering the peakthresh may result in noise being recognised as a peak and thereby generating false data.
# >start high e.g. 0.1 and lower as appropriate

# %%
eng.update_config(masslb = 10000, massub = 20000, minmz = 500, peakthresh = 0.02)

# eng.update_config(masslb = 10000, massub = 20000, peakthresh = 0.01, datanorm = 0, 
#                  beta = 0, peaknorm = 0, exnorm = 0, numit=100, numz=50,
#                  endz=100, startz=10,zzsig=1.0, psig=1.0,mzsig=1.0,psfun=0,msig=0.0,molig=0.0,
#                  massbins=1.0,mtabsig=0.0, subbuff=0.0, subtype=2, mzbins=0.0, 
#                  peakwindow=10.0, smooth = 0)
# eng.update_config(masslb = 10000, massub = 20000, minmz = 500, peakthresh = 0.02, mzbins = 0,
#         linflag = 2,
#         adductmass = 1.007276467,
#         # Narrow Charge and Mass Range
#         startz = 1,
#         endz = 50,

#         # Increase mass resolution and lower peak shape
#         massbins = 10,
#         mzsig = 1,
#         psfun = 0,
#         isotopemode = 0,
#         molig = 0,
#         msig = 0,
#         numit = 50,
#         zzsig = 1,
#         psig = 1,
#         poolflag = 2)

eng.process_data()
eng.run_unidec()
eng.pick_peaks()
eng.integrate_all()
# Out:
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.08421630000000135
# Execution Time: 14.437737599999998
# Execution Time: 0.35775999999999897
# Peak info saved to: UniDec_Figures_and_Files\.hdf5_extracts.txt

# %%
eng.plot_all(dtype = 'data2', combine = False, cmap = 'viridis')

# %%
eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [12000, 14000])

# %%
eng.upload_map(map_path)
# Out:
# (         Reaction       Species  Concentration Units      Mass Reagent_Type  \
#  0  CTB Sortase 10        CTB-H6          100.0    uM  13597.42      Protein
#  1  CTB Sortase 10  CTB-labelled            NaN    uM  13151.97      Protein
#
#    Sequence
#  0      NaN
#  1      NaN  ,
#              Type        Reaction Time  Injection  Species  Valid
#  Well ID
#  1        Protein  CTB Sortase 10    0          1      NaN   True
#  2        Protein  CTB Sortase 10   15          1      NaN   True
#  3        Protein  CTB Sortase 10   30          1      NaN   True
#  4        Protein  CTB Sortase 10   45          1      NaN   True
#  5        Protein  CTB Sortase 10   60          1      NaN   True
#  6        Protein  CTB Sortase 10   90          2      NaN   True
#  7        Protein  CTB Sortase 10  105          2      NaN   True
#  8        Protein  CTB Sortase 10  120          2      NaN   True
#  9        Protein  CTB Sortase 10  150          2      NaN   True
#  10       Protein  CTB Sortase 10  180          2      NaN   True)

# %%
eng.pmap
# Out:
#             Type        Reaction Time  Injection  Species  Valid
# Well ID
# 1        Protein  CTB Sortase 10    0          1      NaN   True
# 2        Protein  CTB Sortase 10   15          1      NaN   True
# 3        Protein  CTB Sortase 10   30          1      NaN   True
# 4        Protein  CTB Sortase 10   45          1      NaN   True
# 5        Protein  CTB Sortase 10   60          1      NaN   True
# 6        Protein  CTB Sortase 10   90          2      NaN   True
# 7        Protein  CTB Sortase 10  105          2      NaN   True
# 8        Protein  CTB Sortase 10  120          2      NaN   True
# 9        Protein  CTB Sortase 10  150          2      NaN   True
# 10       Protein  CTB Sortase 10  180          2      NaN   True

# %%
eng.speciesmap
# Out:
#          Reaction       Species  Concentration Units      Mass Reagent_Type  \
# 0  CTB Sortase 10        CTB-H6          100.0    uM  13597.42      Protein
# 1  CTB Sortase 10  CTB-labelled            NaN    uM  13151.97      Protein
#
#   Sequence
# 0      NaN
# 1      NaN

# %%
eng.process_maps()

# %%
eng.peak_match(silent = True)

# %%
eng.normalise_peaks(silent = True)

# %%
eng.plot_data()

# %%
for key, df in eng.data_df.items():
    for species in df.columns:
        group = np.array(df[species])
        if ~np.all((group==0)):
            plt.scatter(df[species].index, group, label=species, marker='x')
            pass
            
#             df[species].plot.scatter(label = species)
np.array(df[species])
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.04495928, 0.05579782, 0.06767455])

# %%
# eng.invalidate(60, 'Time')
eng.plot_data()
# Out:
# Time:60 successfully invalidated
# Time:60 successfully invalidated

# %%
# eng.plot_data(plot_type='scatter')
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1522         try:
# -> 1523             ret = self.converter.convert(x, self.units, self)
#    1524         except Exception as e:
#
# ~\Anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-18-e71d2ce28bcd> in <module>
# ----> 1 eng.plot_data(plot_type='scatter')
#
# ~\Documents\GitHub\UniDec\unidec_modules\v3_SeqChrom.py in plot_data(self, plot_type, species, groupby, datatype)
#     948                         plt.legend(bbox_to_anchor=(1,1), loc="upper left")
#     949                         plt.ylim(0, 1.0)
# --> 950                         plt.xlim(0, np.max(df[species].index))
#     951                 plt.show()
#     952
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xlim(*args, **kwargs)
#    1563     if not args and not kwargs:
#    1564         return ax.get_xlim()
# -> 1565     ret = ax.set_xlim(*args, **kwargs)
#    1566     return ret
#    1567
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3293         self._process_unit_info(xdata=(left, right))
#    3294         left = self._validate_converted_limits(left, self.convert_xunits)
# -> 3295         right = self._validate_converted_limits(right, self.convert_xunits)
#    3296
#    3297         if left is None or right is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _validate_converted_limits(self, limit, convert)
#    3206         """
#    3207         if limit is not None:
# -> 3208             converted_limit = convert(limit)
#    3209             if (isinstance(converted_limit, Real)
#    3210                     and not np.isfinite(converted_limit)):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in convert_xunits(self, x)
#     173         if ax is None or ax.xaxis is None:
#     174             return x
# --> 175         return ax.xaxis.convert_units(x)
#     176
#     177     def convert_yunits(self, y):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1523             ret = self.converter.convert(x, self.units, self)
#    1524         except Exception as e:
# -> 1525             raise munits.ConversionError('Failed to convert value(s) to axis '
#    1526                                          f'units: {x!r}') from e
#    1527         return ret
#
# ConversionError: Failed to convert value(s) to axis units: '90'

# %%
eng.initial_rate(thresh=0.8)

# %%
eng.ratedict
