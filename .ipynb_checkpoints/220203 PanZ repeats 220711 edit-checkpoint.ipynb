# %%
from unidec_modules.v3_SeqChrom import *

# %%
eng = SeqChrom()
# Out:
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
# spectra = "D:\\220202 mass spec\\processed/220202 PanZ 2 hrs repeats_34257_GB3_01_82732.d.mzML"

# spectra = "D:\\220203 mass spec\\processed/220203 PanZ 2 hrs repeats_34263_RA4_01_82765.d.mzML"


plate_map = "C:/Users/cm19ljc/Documents/GitHub/UniDec/reaction maps/PanZ repeats.xlsx"

# %%
# eng.load_mzml(spectra, clear_hdf5=True)
# eng.config.chrom_peak_width = 0.6
# eng.get_chrom_peaks(lb = 1, ub = 5.5) 
# eng.add_chrom_peaks2() 
# eng.plot_tic(peak_windows = True)

spectra_paths = ["D:\\220202 mass spec\\processed/220202 PanZ 2 hrs repeats_34257_GB3_01_82732.d.mzML",
                 "D:\\220203 mass spec\\processed/220203 PanZ 2 hrs repeats_34263_RA4_01_82765.d.mzML",
                 "D:\\220207 mass spec\\processed/220207 PanZ repeats_342834_BE8_01_82841.d.mzML",
]
plate_map = "C:/Users/cm19ljc/Documents/GitHub/UniDec/reaction maps/PanZ repeats x15.xlsx"
eng.load_multi_mzml(spectra_paths, plot = True, clear_hdf5 = True)
# Out:
# Error: No HDF5 file present. Please create an HDF5 file first
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000024CA69D5B50>
# Reading mzML: D:\220202 mass spec\processed/220202 PanZ 2 hrs repeats_34257_GB3_01_82732.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\220202 mass spec\processed/220202 PanZ 2 hrs repeats_34257_GB3_01_82732.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1309 2
# Noise Level: 0.07545038998933104 Window: 0.2
# Bad Peak [0.418967   0.28037518] 0.23773299999999997 [0.418967, 0.6567]
# 1.14297 0.21611000000000002
# 2.10723 0.16206000000000031
# 3.02155 0.19943
# 3.95617 0.19932999999999979
# 4.91147 0.14949000000000012
# Getting scans: [122, 174]
# Length merge axis: 38522
# Getting scans: [349, 388]
# Length merge axis: 39486
# Getting scans: [572, 620]
# Length merge axis: 38552
# Getting scans: [797, 845]
# Length merge axis: 38817
# Getting scans: [1025, 1061]
# Length merge axis: 38539
# 4
# 5
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000024CB5DA2C10>
# Reading mzML: D:\220203 mass spec\processed/220203 PanZ 2 hrs repeats_34263_RA4_01_82765.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\220203 mass spec\processed/220203 PanZ 2 hrs repeats_34263_RA4_01_82765.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1307 2
# Noise Level: 0.0683366221327026 Window: 0.2
# Bad Peak [0.418283   0.25253677] 0.237717 [0.418283, 0.656]
# 1.22545 0.20777
# 2.1481 0.18698000000000015
# 3.0916 0.18698000000000015
# 4.02245 0.19528999999999996
# 4.96172 0.18703000000000003
# Getting scans: [139, 189]
# Length merge axis: 38451
# Getting scans: [364, 409]
# Length merge axis: 37997
# Getting scans: [590, 635]
# Length merge axis: 38213
# Getting scans: [814, 861]
# Length merge axis: 38463
# Getting scans: [1040, 1085]
# Length merge axis: 38206
# 4
# 10
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x0000024CB5DA0DC0>
# Reading mzML: D:\220207 mass spec\processed/220207 PanZ repeats_342834_BE8_01_82841.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\220207 mass spec\processed/220207 PanZ repeats_342834_BE8_01_82841.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1306 2
# Noise Level: 0.07736004346852948 Window: 0.2
# Bad Peak [0.41555    0.79366441] 0.254383 [0.41555, 0.669933]
# 1.22698 0.23692000000000002
# 2.14983 0.21614999999999984
# 3.08102 0.21614999999999984
# 4.02452 0.1620200000000005
# 4.9513 0.19119000000000064
# Getting scans: [134, 191]
# Length merge axis: 38478
# Getting scans: [359, 411]
# Length merge axis: 38420
# Getting scans: [584, 636]
# Length merge axis: 38729
# Getting scans: [810, 849]
# Length merge axis: 38094
# Getting scans: [1035, 1081]
# Length merge axis: 38416
# 4
# 15
# 15
# False

# %%
# if eng.ticdat[:, 0].max() > 100: 
#     eng.ticdat[:, 0] = eng.tic[:, 0] = eng.ticdat[:, 0]/60 # add in check in code?

# %%
help(eng.update_config)
# Out:
# Help on method update_config in module unidec_modules.v3_SeqChrom:
#
# update_config(minmz='', maxmz='', massub=10000, masslb=100000, peakthresh=0.01, subtype=2, subbuff=100, datanorm=0, numit=100, massbins=1, mzsig=0, startz=10, endz=100, zzsig=1, psig=1, beta=0, psfun=0, peaknorm=0, peakwindow=10, exnorm=0, numz=50, mtabsig=0.0, molig=0.0, mzbins=0.0, msig=0.0, smooth=0, reductionpercent=0.0, aggressive=0, rawflag=0, nativezub=1000.0, nativezlb=-1000.0, poolflag=2, noiseflag=0, linflag=2, isotopemode=0, baselineflag=1, orbimode=0, peakplotthresh=0.1, adductmass=1.007276467, intthresh=0) method of unidec_modules.v3_SeqChrom.SeqChrom instance
#     [summary]
#
#     Args:
#         minmz (str, optional): [description]. Defaults to "".
#         maxmz (str, optional): [description]. Defaults to "".
#         massub (int, optional): [description]. Defaults to 10000.
#         masslb (int, optional): [description]. Defaults to 100000.
#         peakthresh (float, optional): [description]. Defaults to 0.01.
#         subtype (int, optional): [background subtraction]. Defaults to 2.
#         subbuff (int, optional): [background subtraction amount (subtract curved) 0 = 0ff,
#         100 = good amount when on]. Defaults to 100.
#         datanorm (int, optional): [data normalisation]. Defaults to 0.
#         numit (int, optional): [number of iterations]. Defaults to 100.
#         massbins (int, optional): [description]. Defaults to 1.
#         mzsig (int, optional): [description]. Defaults to 0.
#         startz (int, optional): [description]. Defaults to 10.
#         endz (int, optional): [description]. Defaults to 100.
#         zzsig (int, optional): [charge smooth width (smooth charge state distributions)]. Defaults to 1.
#         psig (int, optional): [smooth nearby points (point smooth width, some = 1)]. Defaults to 0.
#         beta (int, optional): [suppress artifacts (beta, some = 50)]. Defaults to 50.
#         psfun (int, optional): [Peak shape function (gaussian, lorentzian, split G/L)]. Defaults to 0.
#         peaknorm (int, optional): [description]. Defaults to 0.
#         peakwindow (int, optional): [description]. Defaults to 10.
#         exnorm (int, optional): [description]. Defaults to 0.

# %%
eng.update_config(masslb = 10000, massub = 20000, peakthresh = 0.02, peakwindow = 5, minmz="350")
eng.process_data()
eng.run_unidec()
eng.pick_peaks()
eng.integrate_all()
# Out:
# Failed Automatic Peak Width: list indices must be integers or slices, not tuple
# []
# Execution Time: 0.14115990000000522
# Execution Time: 41.3514431
# Execution Time: 0.9155640000000034
# Peak info saved to: UniDec_Figures_and_Files\.hdf5_extracts.txt

# %%
eng.plot_all(dtype = 'data2', combine = False, cmap = 'viridis')

# %%
eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [14000, 17000])

# %%
eng.upload_map(plate_map)
# Out:
# (  Reaction      Species  Concentration Units     Mass Reagent_Type Sequence
#  0     PanZ         PanZ          100.0    uM  16223.0      Protein      NaN
#  1     PanZ  PanZ-GVSEYG            NaN    uM  15623.0      Protein      NaN
#  2     PanZ      PanZ-OH            NaN    uM  15029.0      Protein      NaN
#  3     PanZ      Unknown            NaN   NaN  15459.0      Protein      NaN,
#              Type Reaction Time  Sample  Species  Valid
#  Well ID
#  1        Protein     PanZ  120       1      NaN   True
#  2        Protein     PanZ  120       2      NaN   True
#  3        Protein     PanZ  120       3      NaN   True
#  4        Protein     PanZ  120       4      NaN   True
#  5        Protein     PanZ  120       5      NaN   True
#  6        Protein     PanZ  120       6      NaN   True
#  7        Protein     PanZ  120       7      NaN   True
#  8        Protein     PanZ  120       8      NaN   True
#  9        Protein     PanZ  120       9      NaN   True
#  10       Protein     PanZ  120      10      NaN   True
#  11       Protein     PanZ  120      11      NaN   True
#  12       Protein     PanZ  120      12      NaN   True
#  13       Protein     PanZ  120      13      NaN   True
#  14       Protein     PanZ  120      14      NaN   True
#  15       Protein     PanZ  120      15      NaN   True)

# %%
eng.pmap
# Out:
#             Type Reaction Time  Sample  Species  Valid
# Well ID
# 1        Protein     PanZ  120       1      NaN   True
# 2        Protein     PanZ  120       2      NaN   True
# 3        Protein     PanZ  120       3      NaN   True
# 4        Protein     PanZ  120       4      NaN   True
# 5        Protein     PanZ  120       5      NaN   True
# 6        Protein     PanZ  120       6      NaN   True
# 7        Protein     PanZ  120       7      NaN   True
# 8        Protein     PanZ  120       8      NaN   True
# 9        Protein     PanZ  120       9      NaN   True
# 10       Protein     PanZ  120      10      NaN   True
# 11       Protein     PanZ  120      11      NaN   True
# 12       Protein     PanZ  120      12      NaN   True
# 13       Protein     PanZ  120      13      NaN   True
# 14       Protein     PanZ  120      14      NaN   True
# 15       Protein     PanZ  120      15      NaN   True

# %%
eng.speciesmap
# Out:
#   Reaction      Species  Concentration Units     Mass Reagent_Type Sequence
# 0     PanZ         PanZ          100.0    uM  16223.0      Protein      NaN
# 1     PanZ  PanZ-GVSEYG            NaN    uM  15623.0      Protein      NaN
# 2     PanZ      PanZ-OH            NaN    uM  15029.0      Protein      NaN
# 3     PanZ      Unknown            NaN   NaN  15459.0      Protein      NaN

# %%
eng.process_maps(groupby = 'Reaction', variable = 'Sample')

# %%
eng.pmap2
# Out:
#             Type Reaction Time  Sample                                Species  \
# Well ID
# 1        Protein     PanZ  120       1  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 2        Protein     PanZ  120       2  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 3        Protein     PanZ  120       3  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 4        Protein     PanZ  120       4  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 5        Protein     PanZ  120       5  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 6        Protein     PanZ  120       6  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 7        Protein     PanZ  120       7  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 8        Protein     PanZ  120       8  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 9        Protein     PanZ  120       9  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 10       Protein     PanZ  120      10  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 11       Protein     PanZ  120      11  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 12       Protein     PanZ  120      12  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 13       Protein     PanZ  120      13  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 14       Protein     PanZ  120      14  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
# 15       Protein     PanZ  120      15  [PanZ, PanZ-GVSEYG, PanZ-OH, Unknown]
#
#          Valid                                               PanZ  \
# Well ID
# 1         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 2         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 3         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 4         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 5         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 6         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 7         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 8         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 9         True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 10        True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 11        True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 12        True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 13        True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 14        True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
# 15        True  <PanZ(Reaction = PanZ, Species = PanZ, Concent...
#
#                                                PanZ-GVSEYG  \
# Well ID
# 1        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 2        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 3        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 4        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 5        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 6        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 7        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 8        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 9        <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 10       <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 11       <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 12       <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 13       <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 14       <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
# 15       <PanZ-GVSEYG(Reaction = PanZ, Species = PanZ-G...
#
#                                                    PanZ-OH  \
# Well ID
# 1        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 2        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 3        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 4        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 5        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 6        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 7        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 8        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 9        <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 10       <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 11       <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 12       <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 13       <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 14       <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
# 15       <PanZ-OH(Reaction = PanZ, Species = PanZ-OH, C...
#
#                                                    Unknown  \
# Well ID
# 1        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 2        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 3        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 4        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 5        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 6        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 7        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 8        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 9        <Unknown(Reaction = PanZ, Species = Unknown, C...
# 10       <Unknown(Reaction = PanZ, Species = Unknown, C...
# 11       <Unknown(Reaction = PanZ, Species = Unknown, C...
# 12       <Unknown(Reaction = PanZ, Species = Unknown, C...
# 13       <Unknown(Reaction = PanZ, Species = Unknown, C...
# 14       <Unknown(Reaction = PanZ, Species = Unknown, C...
# 15       <Unknown(Reaction = PanZ, Species = Unknown, C...
#
#                                                    Spectra
# Well ID
# 1        <metaunidec.mudstruct.Spectrum object at 0x000...
# 2        <metaunidec.mudstruct.Spectrum object at 0x000...
# 3        <metaunidec.mudstruct.Spectrum object at 0x000...
# 4        <metaunidec.mudstruct.Spectrum object at 0x000...
# 5        <metaunidec.mudstruct.Spectrum object at 0x000...
# 6        <metaunidec.mudstruct.Spectrum object at 0x000...
# 7        <metaunidec.mudstruct.Spectrum object at 0x000...
# 8        <metaunidec.mudstruct.Spectrum object at 0x000...
# 9        <metaunidec.mudstruct.Spectrum object at 0x000...
# 10       <metaunidec.mudstruct.Spectrum object at 0x000...
# 11       <metaunidec.mudstruct.Spectrum object at 0x000...
# 12       <metaunidec.mudstruct.Spectrum object at 0x000...
# 13       <metaunidec.mudstruct.Spectrum object at 0x000...
# 14       <metaunidec.mudstruct.Spectrum object at 0x000...
# 15       <metaunidec.mudstruct.Spectrum object at 0x000...

# %% [markdown]
# invalidate data using eng.invalidate()

# %%
eng.peak_match(silent = True)
eng.normalise_peaks(silent = True)

eng.plot_data(plot_type='bar', groupby='Sample')

# %%
df = eng.data_df['PanZ']
means, std = df.mean(), df.std()
means.index
plt.errorbar(x=np.array(means.index), y=np.array(means), yerr=np.array(std), fmt='o', marker = ".",
             
             capsize = 10, color = 'darkblue')
plt.bar(x=np.array(means.index), height=np.array(means), color = 'lightblue')
plt.show()

# %%
eng.invalidate([2, 5, 14], group = 'Sample')
# Out:
# Sample:2 successfully invalidated
# Sample:2 successfully invalidated
# Sample:5 successfully invalidated
# Sample:5 successfully invalidated
# Sample:14 successfully invalidated
# Sample:14 successfully invalidated

# %%
df = eng.data_df['PanZ']
means, std = df.mean(), df.std()

plt.show()
eng.plot_data(plot_type='bar', groupby='Sample')

# %%
plt.errorbar(x=np.array(means.index), y=np.array(means), yerr=np.array(std), fmt='o', marker = ".",
             
             capsize = 10, color = 'darkblue')
plt.bar(x=np.array(means.index), height=np.array(means), color = 'lightblue')
plt.ylabel("Percentage Intensity")
plt.xlabel("Species")
plt.show()
