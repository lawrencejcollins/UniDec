# %%
from unidec_modules.v3_SeqChrom import *

# %%
eng = SeqChrom()
# Out:
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
# 10% H7D
# spectra_paths = "D:\\211125 mass spec\\processed\\211124 CTB GV tc part 1_337339_RC3_01_80616.d.mzML", "D:\\211125 mass spec\\processed\\211124 CTB GV tc part 2_337340_RC6_01_80618.d.mzML"
# map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\CTB h7d time course 10pc.xlsx"

# 25% H7D

spectra_paths = ("D:\\211129 mass spec\\processed\\211129 CTB-GV H7D 25 p1_337825_BB3_01_80765.d.mzML",
"D:\\211129 mass spec\\processed\\211129 CTB GV H7D 25 p2_337841_BD1_01_80779.d.mzML")
map_path = "C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\reaction maps\\CTB h7d time course 25pc.xlsx"
# eng.load_mzml(spectra_path)

# %%
eng.load_multi_mzml(spectra_paths, plot = True)
# Out:
# Error: No HDF5 file present. Please create an HDF5 file first
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x000001F27EF5FF10>
# Opening HDF5 File: D:\211129 mass spec\processed\211129 CTB-GV H7D 25 p1_337825_BB3_01_80765.d.hdf5
# Reading mzML: D:\211129 mass spec\processed\211129 CTB-GV H7D 25 p1_337825_BB3_01_80765.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211129 mass spec\processed\211129 CTB-GV H7D 25 p1_337825_BB3_01_80765.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1307 2
# Noise Level: 0.04653224129822865 Window: 0.2
# 0.70285 0.22506700000000002
# 1.20587 0.19537000000000004
# 2.13277 0.19119999999999981
# 3.07642 0.19114999999999993
# 4.02412 0.19115000000000038
# 4.94695 0.17865999999999982
# Getting scans: [138, 185]
# Length merge axis: 38092
# Getting scans: [360, 406]
# Length merge axis: 38128
# Getting scans: [589, 635]
# Length merge axis: 38599
# Getting scans: [814, 860]
# Length merge axis: 38601
# Getting scans: [1037, 1080]
# Length merge axis: 38408
# 4
# 5
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
#
# UniDec Engine v.5.0.1
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_bin\UniDec.exe
# <unidec_modules.v3_SeqChrom.SeqChrom object at 0x000001F2280842E0>
# Opening HDF5 File: D:\211129 mass spec\processed\211129 CTB GV H7D 25 p2_337841_BD1_01_80779.d.hdf5
# Reading mzML: D:\211129 mass spec\processed\211129 CTB GV H7D 25 p2_337841_BD1_01_80779.d.mzML
# [Warning] Not index found and build_index_from_scratch is False
# Converted to gzip file to improve speed: D:\211129 mass spec\processed\211129 CTB GV H7D 25 p2_337841_BD1_01_80779.d.mzML.gz
# Error getting TIC in mzML; trying to make it...
# C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec_modules\mzMLimporter.py:311: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.data = np.array(self.data)
# Imported Data. Constructing TIC
# Done
# 1309 2
# Noise Level: 0.07679702566289233 Window: 0.2
# 0.61875 0.24188299999999996
# 1.15968 0.18287999999999993
# 2.09088 0.21189999999999998
# 3.0303 0.16622000000000003
# 3.9739 0.17039000000000026
# 4.91738 0.2036800000000003
# Getting scans: [126, 170]
# Length merge axis: 37995
# Getting scans: [348, 399]
# Length merge axis: 38902
# Getting scans: [576, 616]
# Length merge axis: 38377
# Getting scans: [801, 842]
# Length merge axis: 38158
# Getting scans: [1027, 1076]
# Length merge axis: 38239
# 4
# 10
# Error: No HDF5 file present. Please create an HDF5 file first
# 10
# False

# %%
# TIC/time point invalidation 
# add option to delete index in TIC data 
# add option to invalidate specific time/species 
# add option to plot bar chart instead of scatter/line - especially useful for comparison of diff species

# %% [markdown]
# n.b. lowering the peakthresh may result in noise being recognised as a peak and thereby generating false data.
# >start high e.g. 0.1 and lower as appropriate

# %%
eng.update_config(masslb = 12000, massub = 14000, minmz = 775, peakthresh = 0.02)
eng.process_data()
eng.run_unidec()
eng.pick_peaks()
eng.integrate_all()
# Out:
# Error: No HDF5 file present. Please create an HDF5 file first
# Execution Time: 0.15080429999999723
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9a3d0d95ef74> in <module>
#       1 eng.update_config(masslb = 12000, massub = 14000, minmz = 775, peakthresh = 0.02)
# ----> 2 eng.process_data()
#       3 eng.run_unidec()
#       4 eng.pick_peaks()
#       5 eng.integrate_all()
#
# ~\Documents\GitHub\UniDec\metaunidec\mudeng.py in process_data(self)
#      79         self.config.write_hdf5()
#      80         self.out = metaunidec_call(self.config, "-proc")
# ---> 81         self.data.import_hdf5()
#      82         self.update_history()
#      83
#
# ~\Documents\GitHub\UniDec\metaunidec\mudstruct.py in import_hdf5(self, file)
#      37         else:
#      38             self.filename = file
# ---> 39         hdf = h5py.File(file, 'r')
#      40         msdata = hdf.require_group(self.topname)
#      41         keys = list(msdata.keys())
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     410                 name = repr(name).encode('ASCII', 'replace')
#     411             else:
# --> 412                 name = filename_encode(name)
#     413
#     414             if track_order is None:
#
# ~\Anaconda3\lib\site-packages\h5py\_hl\compat.py in filename_encode(filename)
#      17     filenames in h5py for more information.
#      18     """
# ---> 19     filename = fspath(filename)
#      20     if sys.platform == "win32":
#      21         if isinstance(filename, str):
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
eng.plot_all(dtype = 'data2', combine = False, cmap = 'viridis')

# %%
eng.plot_all(dtype = 'massdat', combine = False, cmap = 'viridis', xlim = [12000, 14000])

# %%
eng.upload_map(map_path)

# %%
eng.pmap

# %%
eng.speciesmap

# %%
eng.process_maps()

# %%
eng.peak_match(silent = True)

# %%
eng.normalise_peaks(silent = True)

# %%
eng.plot_data()

# %%
# eng.invalidate(90, 'Time')
eng.plot_data()

# %%
eng.plot_data(plot_type='bar')

# %%
eng.initial_rate(thresh=0.8)

# %%
eng.ratedict

# %%
eng.__dict__

# %%
def foo(bar, result, index):
    print('hello {0}'.format(bar))
    result[index] = "foo"

from threading import Thread

threads = [None] * 10
results = [None] * 10

for i in range(len(threads)):
    threads[i] = Thread(target=foo, args=('world!', results, i))
    threads[i].start()

# do some other stuff

for i in range(len(threads)):
    threads[i].join()

print(" ".join(results))
