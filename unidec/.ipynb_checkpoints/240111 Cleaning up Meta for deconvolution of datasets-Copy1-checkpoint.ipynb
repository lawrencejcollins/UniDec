# %%
from modules.v3_SeqChrom import * # had to remove every instance of unidec.'something' # RUN LATEST VERSION OF MATPLOTLIB
# Out:
# Could not import data reader: unidectools
# Could not import Waters Data Importer

# %%
eng = SeqChrom()
# Out:
# UniDec Engine v.6.0.4
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec\bin\unidec.exe
#
# UniDec Engine v.6.0.4
#
# UniDec Path: C:\Users\cm19ljc\Documents\GitHub\UniDec\unidec\bin\unidec.exe

# %% [markdown]
# Added in option to load multipe mzml files into engine before metaunidec processing.

# %%
spectra = "D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\20230710 4C_24h_1.mzML"
# plate_map = "C:/Users/cm19ljc/Documents/GitHub/UniDec/reaction maps/PanZ sortase time course 1.5 eq gvseyg.xlsx"

# %%
eng.load_mzml(spectra, clear_hdf5=True) # msconvert files are SLOW
# Out:
# Opening Time: 0.013113000000000596
# Reading mzML: D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\20230710 4C_24h_1.mzML
# found chromatogram
# found chromatogram
# Converted to gzip file to improve speed: D:\WORK\20230710 DOE_CTB H6_5M_DAmp\24h\20230710 4C_24h_1.mzML.gz
# Reading Complete
# False

# %%
# eng.config.chrom_peak_width = 0.6
# eng.get_chrom_peaks(lb = 1, ub = 5.5) 
# eng.add_chrom_peaks2() 

if eng.ticdat[:, 0].max() > 100: 
    eng.ticdat[:, 0] = eng.tic[:, 0] = eng.ticdat[:, 0]/60 # add in check in code
    
eng.plot_tic(peak_windows = False)

# %%
t = 1.7,1.9

data = eng.get_data_from_times(t[0], t[1])
eng.data.add_data(data, name = str(t[0]))
# plt.plot(eng.data.data2[:,0], eng.data.data2[:,1])
# Out:
# Scan Range: [406, 453]
# Adding: 1.7 to ms_dataset

# %% [markdown]
# n.b. lowering the peakthresh may result in noise being recognised as a peak and thereby generating false data.
# >start high e.g. 0.1 and lower as appropriate

# %%
# eng.update_config(masslb = 12000, massub = 17000, minmz="750",maxmz="",
        
#         mzbins = 0,
#         linflag = 0,
#         adductmass = 1.007276467,
        
#         startz = 1,
#         endz = 100,

        
#         massbins = 0.1,
#         mzsig = 1,
#         psfun = 0,
#         isotopemode = 1,
#         molig = 0,
#         msig = 1,
#         numit = 100,
#         zzsig = 1,
#         psig = 1,
#         poolflag = 2,)

# UniDec
eng.config.numit = 100
eng.config.zzsig = 1
eng.config.psig = 1
eng.config.beta = 0
eng.config.startz = 1
eng.config.endz = 50
eng.config.numz = 50
eng.config.mzsig = 0.85
eng.config.automzsig = 0
eng.config.psfun = 0
eng.config.psfunz = 0
eng.config.autopsfun = 0
eng.config.massub = 17000
eng.config.masslb = 12000
eng.config.msig = 0
eng.config.molig = 0
eng.config.massbins = 1
eng.config.adductmass = 1.007276467
eng.config.baselineflag = 1
eng.config.aggressiveflag = 0
eng.config.noiseflag = 0
eng.config.isotopemode = 0
eng.config.orbimode = 0

# Other
eng.config.mtabsig = 0
eng.config.poolflag = 2
eng.config.nativezub = 1000
eng.config.nativezlb = -1000
eng.config.inflate = 1
eng.config.linflag = 2
eng.config.integratelb = ""
eng.config.integrateub = ""
eng.config.filterwidth = 20
eng.config.zerolog = -12


# eng.process_data()
eng.run_unidec()
eng.plot_all(dtype = 'massdat', combine = True, cmap = 'brg', show_ints=False)
# eng.pick_peaks()
# eng.integrate_all()
# Out:
# Execution Time: 1.0732448999999633
# Mass Grid Warning: (0,) (0,)
# mz grid Warning: (0,) (0,)

# %%
eng.config.__dict__
# Out:
# {'version': '6.0.4',
#  'inputversion': None,
#  'dtype': numpy.float32,
#  'system': 'Windows',
#  'infname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_input.dat',
#  'outfname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1',
#  'mfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_mfile.dat',
#  'manualfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_manualfile.dat',
#  'smashfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_smashfile.dat',
#  'confname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_conf.dat',
#  'hdf_file': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\20230710 4C_24h_1.hdf5',
#  'ofile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_ofile.dat',
#  'matchfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_match.dat',
#  'peaksfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_peaks.dat',
#  'dirname': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h',
#  'udir': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files',
#  'filename': '20230710 4C_24h_1.hdf5',
#  'extension': '',
#  'deconfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_decon.txt',
#  'errorfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_error.txt',
#  'fitdatfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_fitdat.bin',
#  'massgridfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_massgrid.bin',
#  'massdatfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_mass.txt',
#  'cdrawextracts': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_rawdata.npz',
#  'mzgridfile': 'D:\\WORK\\20230710 DOE_CTB H6_5M_DAmp\\24h\\UniDec_Figures_and_Files\\20230710 4C_24h_1_grid.bin',
#  'cdcreaderpath': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\CDCreader.exe',
#  'UniDecPath': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\unidec.exe',
#  'UniDecDir': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin',
#  'UniDecName': 'unidec.exe',
#  'defaultUnidecDir': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin',
#  'opencommand': 'start "" ',
#  'defaultUnidecName': 'unidec.exe',
#  'iconfile': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\logo.ico',
#  'toplogofile': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\UniDecLogoMR.png',
#  'exampledatadirUC': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\Example Data\\UniChrom',
#  'exampledatadirCD': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\Example Data\\CDMS',
#  'exampledatadir': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\Example Data',
#  'presetdirCD': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\Presets\\CDMS',
#  'presetdir': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\Presets',
#  'h5repackfile': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\h5repack.exe',
#  'recentfileCD': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\recentCD.txt',
#  'recentfile': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\recent.txt',
#  'masstablefile': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\mass_table.csv',
#  'defaultconfig': 'C:\\Users\\cm19ljc\\Documents\\GitHub\\UniDec\\unidec\\bin\\default_conf.dat',
#  'imflag': 0,
#  'cdmsflag': 0,
#  'metamode': -1,
#  'filetype': 1,
#  'autotune': False,
#  'time_window': 2,
#  'chrom_peak_width': 2,
#  'sw_time_window': 1,
#  'sw_scan_offset': 10,
#  'time_start': '',
#  'time_end': '',
#  'twavedict': {1: 'Logarithmic',
#   2: 'Linear',
#   3: 'Power Law',
#   4: 'SLIM poly2',
#   5: 'SLIM poly3'},
#  'backgroundchoices': ['Subtract Minimum',
#   'Subtract Line',
#   'Subtract Curved',
#   'Subtract Constant'],
#  'isotopechoices': ['Isotopes: Off', 'Isotopes: Mono', 'Isotopes: Average'],
#  'figsize': (6, 5),
#  'mass_proton': 1.007276467,
#  'mass_diff_carbon': 1.0033,
#  'polarity': 'Positive',
#  'publicationmode': 1,
#  'discreteplot': 0,
#  'cmap': 'nipy_spectral',
#  'peakcmap': 'rainbow',
#  'spectracmap': 'rainbow',
#  'rawflag': 0,
#  'minmz': 750.0,
#  'maxmz': 1000000.0,
#  'intscale': 'Linear',
#  'error': 0,
#  'runtime': 0,
#  'mindt': '',
#  'maxdt': '',
#  'zout': 0,
#  'pusher': 0,
#  'temp': 25,
#  'pressure': 2,
#  'volt': 50,
#  'to': 0,
#  'driftlength': 0.18202,
#  'tcal1': 0.3293,
#  'tcal2': 6.3597,
#  'tcal3': 0,
#  'tcal4': 0,
#  'edc': 1.57,
#  'gasmass': 4.002602,
#  'twaveflag': 0,
#  'batchflag': 0,
#  'procflag': 0,
#  'massdatnormtop': 0,
#  'mfileflag': 0,
#  'manualfileflag': 0,
#  'kendrickmass': None,
#  'masslist': array([], dtype=float64),
#  'matchlist': [],
#  'oligomerlist': array([], dtype='<U32'),
#  'manuallist': array([], dtype=float64),
#  'smashlist': [],
#  'smashflag': 0,
#  'zoffs': [],
#  'smashrange': [],
#  'massoffset': 0,
#  'extractshape': 0,
#  'gridparams': None,
#  'griddecon': None,
#  'defectparams': None,
#  'defectcomparefiles': [None, None],
#  'matchtolerance': 1000,
#  'avgscore': 0,
#  'detectoreffva': 0,
#  'mzbins': 0,
#  'smooth': 0,
#  'subbuff': 100,
#  'subtype': 2,
#  'intthresh': 0,
#  'reductionpercent': 0.0,
#  'numit': 100,
#  'zzsig': 1,
#  'psig': 1,
#  'beta': 0,
#  'startz': 1,
#  'endz': 50,
#  'numz': 50,
#  'mzsig': 0.85,
#  'automzsig': 0,
#  'psfun': 0,
#  'psfunz': 0,
#  'autopsfun': 0,
#  'massub': 17000,
#  'masslb': 12000,
#  'msig': 0,
#  'molig': 0,
#  'massbins': 1,
#  'adductmass': 1.007276467,
#  'baselineflag': 1,
#  'aggressiveflag': 0,
#  'noiseflag': 0,
#  'isotopemode': 0,
#  'orbimode': 0,
#  'mtabsig': 0,
#  'poolflag': 2,
#  'nativezub': 1000,
#  'nativezlb': -1000,
#  'inflate': 1,
#  'linflag': 2,
#  'integratelb': '',
#  'integrateub': '',
#  'filterwidth': 20,
#  'zerolog': -12,
#  'peakwindow': 10,
#  'peakthresh': 0.01,
#  'peakplotthresh': 0.1,
#  'separation': 0.025,
#  'peaknorm': 0,
#  'exwindow': 0,
#  'exchoice': 0,
#  'exchoicez': 1,
#  'exthresh': 10,
#  'exnorm': 0,
#  'exnormz': 0,
#  'datanorm': 0,
#  'numtot': 20,
#  'crossover': 100,
#  'smoothdt': 0,
#  'subbufdt': 0,
#  'ccslb': 100,
#  'ccsub': 25000,
#  'nativeccsub': 20000,
#  'nativeccslb': -20000,
#  'dtsig': 0.2,
#  'ccsbins': 100,
#  'compressflag': 1,
#  'csig': 0,
#  'CDslope': 0.2074,
#  'CDzbins': 1,
#  'CDres': 0,
#  'doubledec': False,
#  'kernel': '',
#  'cmaps': ['Accent',
#   'Accent_r',
#   'Blues',
#   'Blues_r',
#   'BrBG',
#   'BrBG_r',
#   'BuGn',
#   'BuGn_r',
#   'BuPu',
#   'BuPu_r',
#   'CMRmap',
#   'CMRmap_r',
#   'Dark2',
#   'Dark2_r',
#   'GnBu',
#   'GnBu_r',
#   'Greens',
#   'Greens_r',
#   'Greys',
#   'Greys_r',
#   'OrRd',
#   'OrRd_r',
#   'Oranges',
#   'Oranges_r',
#   'PRGn',
#   'PRGn_r',
#   'Paired',
#   'Paired_r',
#   'Pastel1',
#   'Pastel1_r',
#   'Pastel2',
#   'Pastel2_r',
#   'PiYG',
#   'PiYG_r',
#   'PuBu',
#   'PuBuGn',
#   'PuBuGn_r',
#   'PuBu_r',
#   'PuOr',
#   'PuOr_r',
#   'PuRd',
#   'PuRd_r',
#   'Purples',
#   'Purples_r',
#   'RdBu',
#   'RdBu_r',
#   'RdGy',
#   'RdGy_r',
#   'RdPu',
#   'RdPu_r',
#   'RdYlBu',
#   'RdYlBu_r',
#   'RdYlGn',
#   'RdYlGn_r',
#   'Reds',
#   'Reds_r',
#   'Set1',
#   'Set1_r',
#   'Set2',
#   'Set2_r',
#   'Set3',
#   'Set3_r',
#   'Spectral',
#   'Spectral_r',
#   'Wistia',
#   'Wistia_r',
#   'YlGn',
#   'YlGnBu',
#   'YlGnBu_r',
#   'YlGn_r',
#   'YlOrBr',
#   'YlOrBr_r',
#   'YlOrRd',
#   'YlOrRd_r',
#   'afmhot',
#   'afmhot_r',
#   'autumn',
#   'autumn_r',
#   'binary',
#   'binary_r',
#   'bone',
#   'bone_r',
#   'brg',
#   'brg_r',
#   'bwr',
#   'bwr_r',
#   'cividis',
#   'cividis_r',
#   'cool',
#   'cool_r',
#   'coolwarm',
#   'coolwarm_r',
#   'copper',
#   'copper_r',
#   'cubehelix',
#   'cubehelix_r',
#   'flag',
#   'flag_r',
#   'gist_earth',
#   'gist_earth_r',
#   'gist_gray',
#   'gist_gray_r',
#   'gist_heat',
#   'gist_heat_r',
#   'gist_ncar',
#   'gist_ncar_r',
#   'gist_rainbow',
#   'gist_rainbow_r',
#   'gist_stern',
#   'gist_stern_r',
#   'gist_yarg',
#   'gist_yarg_r',
#   'gnuplot',
#   'gnuplot2',
#   'gnuplot2_r',
#   'gnuplot_r',
#   'gray',
#   'gray_r',
#   'hot',
#   'hot_r',
#   'hsv',
#   'hsv_r',
#   'inferno',
#   'inferno_r',
#   'jet',
#   'jet_r',
#   'magma',
#   'magma_r',
#   'nipy_spectral',
#   'nipy_spectral_r',
#   'ocean',
#   'ocean_r',
#   'pink',
#   'pink_r',
#   'plasma',
#   'plasma_r',
#   'prism',
#   'prism_r',
#   'rainbow',
#   'rainbow_r',
#   'seismic',
#   'seismic_r',
#   'spring',
#   'spring_r',
#   'summer',
#   'summer_r',
#   'tab10',
#   'tab10_r',
#   'tab20',
#   'tab20_r',
#   'tab20b',
#   'tab20b_r',
#   'tab20c',
#   'tab20c_r',
#   'terrain',
#   'terrain_r',
#   'turbo',
#   'turbo_r',
#   'twilight',
#   'twilight_r',
#   'twilight_shifted',
#   'twilight_shifted_r',
#   'viridis',
#   'viridis_r',
#   'winter',
#   'winter_r'],
#  'cmaps2': ['Accent',
#   'Accent_r',
#   'Blues',
#   'Blues_r',
#   'BrBG',
#   'BrBG_r',
#   'BuGn',
#   'BuGn_r',
#   'BuPu',
#   'BuPu_r',
#   'CMRmap',
#   'CMRmap_r',
#   'Dark2',
#   'Dark2_r',
#   'GnBu',
#   'GnBu_r',
#   'Greens',
#   'Greens_r',
#   'Greys',
#   'Greys_r',
#   'OrRd',
#   'OrRd_r',
#   'Oranges',
#   'Oranges_r',
#   'PRGn',
#   'PRGn_r',
#   'Paired',
#   'Paired_r',
#   'Pastel1',
#   'Pastel1_r',
#   'Pastel2',
#   'Pastel2_r',
#   'PiYG',
#   'PiYG_r',
#   'PuBu',
#   'PuBuGn',
#   'PuBuGn_r',
#   'PuBu_r',
#   'PuOr',
#   'PuOr_r',
#   'PuRd',
#   'PuRd_r',
#   'Purples',
#   'Purples_r',
#   'RdBu',
#   'RdBu_r',
#   'RdGy',
#   'RdGy_r',
#   'RdPu',
#   'RdPu_r',
#   'RdYlBu',
#   'RdYlBu_r',
#   'RdYlGn',
#   'RdYlGn_r',
#   'Reds',
#   'Reds_r',
#   'Set1',
#   'Set1_r',
#   'Set2',
#   'Set2_r',
#   'Set3',
#   'Set3_r',
#   'Spectral',
#   'Spectral_r',
#   'Wistia',
#   'Wistia_r',
#   'YlGn',
#   'YlGnBu',
#   'YlGnBu_r',
#   'YlGn_r',
#   'YlOrBr',
#   'YlOrBr_r',
#   'YlOrRd',
#   'YlOrRd_r',
#   'afmhot',
#   'afmhot_r',
#   'autumn',
#   'autumn_r',
#   'binary',
#   'binary_r',
#   'bone',
#   'bone_r',
#   'brg',
#   'brg_r',
#   'bwr',
#   'bwr_r',
#   'cividis',
#   'cividis_r',
#   'cool',
#   'cool_r',
#   'coolwarm',
#   'coolwarm_r',
#   'copper',
#   'copper_r',
#   'cubehelix',
#   'cubehelix_r',
#   'flag',
#   'flag_r',
#   'gist_earth',
#   'gist_earth_r',
#   'gist_gray',
#   'gist_gray_r',
#   'gist_heat',
#   'gist_heat_r',
#   'gist_ncar',
#   'gist_ncar_r',
#   'gist_rainbow',
#   'gist_rainbow_r',
#   'gist_stern',
#   'gist_stern_r',
#   'gist_yarg',
#   'gist_yarg_r',
#   'gnuplot',
#   'gnuplot2',
#   'gnuplot2_r',
#   'gnuplot_r',
#   'gray',
#   'gray_r',
#   'hot',
#   'hot_r',
#   'hsv',
#   'hsv_r',
#   'inferno',
#   'inferno_r',
#   'jet',
#   'jet_r',
#   'magma',
#   'magma_r',
#   'nipy_spectral',
#   'nipy_spectral_r',
#   'ocean',
#   'ocean_r',
#   'pink',
#   'pink_r',
#   'plasma',
#   'plasma_r',
#   'prism',
#   'prism_r',
#   'rainbow',
#   'rainbow_r',
#   'seismic',
#   'seismic_r',
#   'spring',
#   'spring_r',
#   'summer',
#   'summer_r',
#   'tab10',
#   'tab10_r',
#   'tab20',
#   'tab20_r',
#   'tab20b',
#   'tab20b_r',
#   'tab20c',
#   'tab20c_r',
#   'terrain',
#   'terrain_r',
#   'turbo',
#   'turbo_r',
#   'twilight',
#   'twilight_r',
#   'twilight_shifted',
#   'twilight_shifted_r',
#   'viridis',
#   'viridis_r',
#   'winter',
#   'winter_r'],
#  'aggressive': 0}

# %%
plt.plot(eng.data.spectra[0].massdat[:,0],eng.data.spectra[0].massdat[:,1])

# %%
d = np.transpose(((eng.data.spectra[0].massdat[:,1]),eng.data.spectra[0].massdat[:,0]))
np.savetxt("20230710 4C_24h_1_unidec.txt",d,delimiter=',',header="unidec_export")

# %%
import matplotlib.cm as cm
cm.get_cmap("rainbow")

# %%
eng.data.spectra[0].massdat
# Out:
# array([[11969.,     0.],
#        [11970.,     0.],
#        [11971.,     0.],
#        ...,
#        [17044.,     0.],
#        [17045.,     0.],
#        [17046.,     0.]], dtype=float32)

# %%
import matplotlib as mpl
mpl.colors.Colormap
# Out:
# matplotlib.colors.Colormap

# %%
eng.plot_all(dtype = 'massdat', combine = True, cmap = 'brg', show_ints=False)

# %%
eng.plot_all(dtype = 'massdat', combine = True, cmap = 'brg', xlim = [14000, 17000])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 eng.plot_all(dtype = 'massdat', combine = True, cmap = 'brg', xlim = [14000, 17000])
#
# File ~\Documents\GitHub\UniDec\unidec\modules\v3_SeqChrom.py:849, in SeqChrom.plot_all(self, dtype, show_ints, xlim, combine, cmap, export)
#     846     # if combine == True:
#     847     #     ax.set_xlim(xlim[0], xlim[1]+xcounter)
#     848 if show_ints == True:
# --> 849     ints = s.integrals[x][1]
#     850     if combine == False:
#     851         ax.fill_between(ints[:, 0], ints[:, 1], color = p.color, alpha = 0.1)
#
# AttributeError: 'Spectrum' object has no attribute 'integrals'

# %%
eng.upload_map(plate_map)

# %%
eng.pmap

# %%
eng.speciesmap

# %%
eng.process_maps(groupby = 'Reaction', variable = 'Species')

# %%
eng.pmap2

# %% [markdown]
# invalidate data using eng.invalidate()

# %%
eng.peak_match(silent = True)
eng.normalise_peaks(silent = True)

eng.plot_data(plot_type='bar', groupby='Time')
# eng.invalidate("30")

eng.plot_data(cmap = 'Paired')

# %%
dir(eng)

# %%
eng.speciesmap

# %%
eng.pmap3

# %%
eng.pmap3.PanZ.iloc[2]
